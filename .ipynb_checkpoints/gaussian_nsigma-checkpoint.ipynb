# %% [markdown]
# This notebook will attempt to determine the significance of parameter shift as a function of  gaussian separation.

# %%
from cobaya.run import run
from getdist.mcsamples import MCSamplesFromCobaya
import numpy as np
# %matplotlib inline
import getdist.plots as gdplt
import scipy

import matplotlib.pyplot as plt
from IPython.display import clear_output

import tensorflow as tf
import tensorflow_probability as tfp
tfb = tfp.bijectors
tfd = tfp.distributions
tfk = tf.keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import Callback

import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2284894/4105007507.py in <module>
# ----> 1 from cobaya.run import run
#       2 from getdist.mcsamples import MCSamplesFromCobaya
#       3 import numpy as np
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 import getdist.plots as gdplt
#
# ModuleNotFoundError: No module named 'cobaya'

# %%
separation = 2

#gaussian
info1 = {
    "likelihood": {
        "gaussian_mixture": {
            "means": [0, 0],
            "covs": [[1.0, 0.0],
                     [0.0, 1.0]],
            "derived": True}},
    "params": dict([
        ("a", {
            "prior": {"min": -5, "max": 10},
            "latex": r"\alpha"}),
        ("b", {
            "prior": {"min": -5, "max": 10},
            "ref": 0,
            "proposal": 0.5,
            "latex": r"\beta"}),
        ("derived_a", {
            "latex": r"\alpha^\prime"}),
        ("derived_b", {
            "latex": r"\beta^\prime"})]),
    "sampler": {
        "mcmc": {"Rminus1_stop": 0.005, "max_tries": 1000}}}

# different gaussian
info2 = {
    "likelihood": {
        "gaussian_mixture": {
            "means": [separation, 0],
            "covs": [[1.0, 0.0],
                     [0.0, 1.0]],
            "derived": True}},
    "params": dict([
        ("a", {
            "prior": {"min": -5, "max": 10},
            "latex": r"\alpha"}),
        ("b", {
            "prior": {"min": -5, "max": 10},
            "ref": 0,
            "proposal": 0.5,
            "latex": r"\beta"}),
        ("derived_a", {
            "latex": r"\alpha^\prime"}),
        ("derived_b", {
            "latex": r"\beta^\prime"})]),
    "sampler": {
        "mcmc": {"Rminus1_stop": 0.005, "max_tries": 1000}}}

updated_info1, sampler1 = run(info1)
updated_info2, sampler2 = run(info2)

gdsamples1 = MCSamplesFromCobaya(updated_info1, sampler1.products()["sample"])
gdsamples2 = MCSamplesFromCobaya(updated_info2, sampler2.products()["sample"])
gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot([gdsamples1,gdsamples2], ["a", "b"], filled=True)
# Out:
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 16700.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:-4.971233, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 18:56:35 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.271
# [mcmc]  - Convergence of means: R-1 = 0.995087 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.288
# [mcmc]  - Convergence of means: R-1 = 0.146252 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.268
# [mcmc]  - Convergence of means: R-1 = 0.105209 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.261
# [mcmc]  - Convergence of means: R-1 = 0.084010 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.281
# [mcmc]  - Convergence of means: R-1 = 0.114801 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.034040 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.043540 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.055447 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.291
# [mcmc]  - Convergence of means: R-1 = 0.067188 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.027486 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.018068 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.288
# [mcmc]  - Convergence of means: R-1 = 0.025590 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.046928 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.020177 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.006638 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.003157 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.009118 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.008605 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.013095 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.008646 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.007848 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.004661 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.005471 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.005881 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.009864 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.009793 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.006105 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.004212 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2320 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.002644 after 1856 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.094627 after 2320 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 2320 accepted steps.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 16300.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:-2.181415, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 18:56:39 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.031054 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.257
# [mcmc]  - Convergence of means: R-1 = 0.032605 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.120558 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.020464 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.310
# [mcmc]  - Convergence of means: R-1 = 0.026620 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.058958 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.072858 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.064408 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.075208 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.051929 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.046619 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.042637 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.026698 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.014756 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.013938 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.026092 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.017364 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.008846 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.009063 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.011793 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.014792 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.025750 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.018788 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.019991 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.010887 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.006300 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.008737 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.009029 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2320 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.006643 after 1856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.004618 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2480 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.003996 after 1984 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.110589 after 2480 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 2480 accepted steps.
# [root] *WARNING* outlier fraction 0.00646551724137931
# [root] *WARNING* outlier fraction 0.006048387096774193

# %%
# get parameter difference


# separate dictionary into x,y arrays
a1 = gdsamples1['a']
b1 = gdsamples1['b']
a2 = gdsamples2['a']
b2 = gdsamples2['b']

# init difference arrays
diff_a = np.zeros([len(a1),len(a2)])
diff_b = np.zeros([len(b1),len(b2)])

# take each point in alpha and subtract each beta
for idx1 in range(len(a1)):
    for idx2 in range(len(a2)):
        diff_a[idx1][idx2] = a1[idx1]-a2[idx2]
        pass
    pass

for idx1 in range(len(b1)):
    for idx2 in range(len(b2)):
        diff_b[idx1][idx2] = b1[idx1]-b2[idx2]
        pass
    pass

# flatten to 1d
diff_a = diff_a.flatten()
diff_b = diff_b.flatten()

from getdist.mcsamples import MCSamples

# convert to MCSamples so it can be plotted with gdplot
diff = MCSamples(samples = [diff_a,diff_b],names=['da','db'], labels=['\\Delta \\alpha','\\Delta \\beta'])

from lmfit import Parameters, minimize, report_fit

results = np.stack(plt.hist2d(diff_a,diff_b,bins=[np.linspace(-4,4,15),np.linspace(-4,4,15)])[0])
binx=[]
biny=[]
edge_x = plt.hist2d(diff_a,diff_b,bins=[np.linspace(-4,4,15),np.linspace(-4,4,15)])[1]
edge_y = plt.hist2d(diff_a,diff_b,bins=[np.linspace(-4,4,15),np.linspace(-4,4,15)])[2]

for i in range(len(edge_x)-1):
    binx.append((edge_x[i+1]-edge_x[i])/2 + edge_x[i])
for i in range(len(edge_y)-1):
    biny.append((edge_y[i+1]-edge_y[i])/2 + edge_y[i])

bins=[]
z=[]
xvals = []
yvals = []

for i in range(len(binx)-1):
    for j in range(len(biny)-1):
        xvals.append(binx[i])
        yvals.append(biny[j])
        z.append(results[i][j])

def gaussian2D(x, y, cen_x, cen_y, sig_x, sig_y):
    return np.exp(-(((cen_x-x)/sig_x)**2 + ((cen_y-y)/sig_y)**2)/2.0)

def residuals(p, x, y, z):
    height = p["height"].value
    cen_x = p["centroid_x"].value
    cen_y = p["centroid_y"].value
    sigma_x = p["sigma_x"].value
    sigma_y = p["sigma_y"].value
    return (z - height*gaussian2D(x,y, cen_x, cen_y, sigma_x, sigma_y))

initial = Parameters()
initial.add("height",value=1.)
initial.add("centroid_x",value=0.)
initial.add("centroid_y",value=0.)
initial.add("sigma_x",value=1.)
initial.add("sigma_y",value=1.)

fit = minimize(residuals, initial, args=(xvals,yvals, z))
print(report_fit(fit))

plt.close()
gdplot = gdplt.get_subplot_plotter()
gdplot.triangle_plot(diff, ["da", "db"], filled=True)
# Out:
# [root] Generating grammar tables from /usr/lib/python3.7/lib2to3/Grammar.txt
# [root] Generating grammar tables from /usr/lib/python3.7/lib2to3/PatternGrammar.txt
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 464
#     # data points      = 169
#     # variables        = 5
#     chi-square         = 2.6326e+08
#     reduced chi-square = 1605250.10
#     Akaike info crit   = 2419.73008
#     Bayesian info crit = 2435.37957
# [[Variables]]
#     height:      124594.550 +/- 385.595587 (0.31%) (init = 1)
#     centroid_x: -1.98716990 +/- 0.00537004 (0.27%) (init = 0)
#     centroid_y:  0.01150361 +/- 0.00475964 (41.38%) (init = 0)
#     sigma_x:     1.55394638 +/- 0.00602627 (0.39%) (init = 1)
#     sigma_y:     1.56487827 +/- 0.00489732 (0.31%) (init = 1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(height, sigma_x)     = -0.520
#     C(height, sigma_y)     = -0.500
#     C(centroid_x, sigma_x) = -0.322
#     C(height, centroid_x)  = 0.114
# None

# %%
# Normalizing flow
class Callback(tfk.callbacks.Callback):
    def on_train_begin(self, logs=None):
        self._loss = []
        self._epoch = []
        print("Starting training...")
        
    def on_epoch_begin(self, epoch, logs=None):
        if(epoch % 5 == 0):
            print("Begin Epoch {}...".format(epoch))

    def on_epoch_end(self, epoch, logs=None):
        self._loss.append(logs['loss'])
        self._epoch.append(epoch)
        if((epoch + 1) % 5 == 0):
            print("End Epoch {}. Loss = {:5.5f}. Validation loss = {:5.5f}".format(epoch,logs['loss'],logs['val_loss']))

    def on_train_end(self, logs=None):
#        fig,ax1 = plt.subplots(1,1) #(ax1, ax2) = plt.subplots(1,2)
#        
#        ax1.set_title('loss vs. epoch')
#        ax1.set_xlabel('epoch')
#        ax1.set_ylabel('loss')
#        ax1.plot(self._epoch,self._loss)
#        
        print("Completed training!")

# %%
def sample(n,dist):
    p = dist.sample(n)
    px = p[...,0]
    py = p[...,1]
    return (px,py,p)
    
def train(base,X,Y,n_maf,n,batch_size,permute,n_epochs):
    nsamples=n
    ## NN setup
    # Set up bijector MADE
    made = tfb.AutoregressiveNetwork(params=2, hidden_units=[12,12], activation=tf.math.asinh, kernel_initializer='glorot_uniform')
    bijectors=[]
    if(permute==True):
        _permutations = [np.random.permutation(2) for _ in range(n_maf)]
    else:
        _permutations=False
    
    for i in range(n_maf):
        # the permutation part comes from the code M. Raveri wrote,
        # The x direction does not want to separate, so I want to see if permuting the input can help
        if _permutations:
            #print(_permutations[i])
            bijectors.append(tfb.Permute(_permutations[i].astype(np.int32)))
        # rest by myself
        bijectors.append(tfb.MaskedAutoregressiveFlow(shift_and_log_scale_fn=made))
        
    target_distribution = tfd.TransformedDistribution(
        distribution=tfd.Sample(base),
        bijector=tfb.Chain(bijectors)) 

    
    # now perform the fit
    xdata = np.stack([X, Y], axis=-1)
    ydata = base.sample(nsamples)
    #print(data)
    #plt.scatter(X,Y,s=5)

    # Construct model.
    x_ = tfk.Input(shape=(2,), dtype=tf.float32)
    log_prob_ = target_distribution.log_prob(x_)
    model = tfk.Model(x_, log_prob_)

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01),
                  metrics=['accuracy'],
                  loss=lambda _, log_prob: -log_prob) 

    loss_plot = []
    #batch_size = 1000
    model.fit(x=xdata,
              y=np.zeros((int(2*nsamples), 2), dtype=np.float32),
              batch_size=batch_size,
              epochs=n_epochs,
              steps_per_epoch=n/(2*batch_size),  # Usually `n // batch_size`.
              validation_split=0.2,
              shuffle=True,
              verbose=False,
              callbacks=[Callback()]) #, ydata
    
    # need to create test set.
    #model.evaluate(x=xdata,y=np.zeros(int(nsamples)),callbacks=[Callback()])
    
    return(target_distribution)
    
def plot(x,y,title):
    plt.figure()
    plt.title(title)
    plt.hist2d(x,y,bins = [np.linspace(-7,7,50),np.linspace(-7,7,50)])
    
# defines the distribution we want to map to
trained_dist = tfd.MultivariateNormalDiag(loc=[0.,0.], scale_diag=[1.,1.])

x = diff['da']
y = diff['db']

# train
trained_dist = train(trained_dist,x,y,n_maf=1,n=len(x),batch_size=1000,permute=False,n_epochs=10)# The result should not depend on the change of variables z1<->z2 

# plot modelled dist
tx,ty,txy=sample(10000,trained_dist)
plot(tx,ty,'result')

# plot each MADE
l_bijectors = np.array(trained_dist.bijector.bijectors)#np.flipud()
step_data=txy
for bij in l_bijectors:
    step_data = bij.inverse(step_data)
    plot(step_data[...,0],step_data[...,1],'steps')
# Out:
# Starting training...
# Begin Epoch 0...
# End Epoch 4. Loss = 3.66396. Validation loss = 3.72646
# Begin Epoch 5...
# End Epoch 9. Loss = 3.66379. Validation loss = 3.72522
# Completed training!

# %%
#Compute significance

prob = trained_dist.prob([0.,0.])
print(prob)

n_points = 10000
n_pass = 0

_s = trained_dist.sample(n_points)
_v = trained_dist.prob(_s)
for val in _v:
    if val>prob:
        n_pass+=1

print(n_pass/n_points)
        
n_sigma = np.sqrt(2)*scipy.special.erfinv(n_pass/n_points)
print(n_sigma)
# Out:
# tf.Tensor(0.029482579, shape=(), dtype=float32)
# 0.5708
# 0.7905613643586861

# %% [markdown]
# Now with one example done, lets set up multiprocessing and do the a full run.

# %%
def gen_data(sep):
  ######################
  #
  # Set up distributions
  #
  ######################
  
  #gaussian
  info1 = {
      "likelihood": {
          "gaussian_mixture": {
              "means": [0, 0],
              "covs": [[1.0, 0.0],
                      [0.0, 1.0]],
              "derived": True}},
      "params": dict([
          ("a", {
              "prior": {"min": -5, "max": 10},
              "latex": r"\alpha"}),
          ("b", {
              "prior": {"min": -5, "max": 10},
              "ref": 0,
              "proposal": 0.5,
              "latex": r"\beta"}),
          ("derived_a", {
              "latex": r"\alpha^\prime"}),
          ("derived_b", {
              "latex": r"\beta^\prime"})]),
      "sampler": {
          "mcmc": {"Rminus1_stop": 0.01, "max_tries": 1000}}}

  # different gaussian
  info2 = {
      "likelihood": {
          "gaussian_mixture": {
              "means": [sep, 0],
              "covs": [[1.0, 0.0],
                      [0.0, 1.0]],
              "derived": True}},
      "params": dict([
          ("a", {
              "prior": {"min": -5, "max": 10},
              "latex": r"\alpha"}),
          ("b", {
              "prior": {"min": -5, "max": 10},
              "ref": 0,
              "proposal": 0.5,
              "latex": r"\beta"}),
          ("derived_a", {
              "latex": r"\alpha^\prime"}),
          ("derived_b", {
              "latex": r"\beta^\prime"})]),
      "sampler": {
          "mcmc": {"Rminus1_stop": 0.01, "max_tries": 1000}}}

  updated_info1, sampler1 = run(info1)
  updated_info2, sampler2 = run(info2)

  gdsamples1 = MCSamplesFromCobaya(updated_info1, sampler1.products()["sample"])
  gdsamples2 = MCSamplesFromCobaya(updated_info2, sampler2.products()["sample"])

  # Get difference distribution
  # separate dictionary into x,y arrays
  a1 = gdsamples1['a']
  b1 = gdsamples1['b']
  a2 = gdsamples2['a']
  b2 = gdsamples2['b']

  # init difference arrays
  diff_a = np.zeros([len(a1),len(a2)])
  diff_b = np.zeros([len(b1),len(b2)])

  # take each point in alpha and subtract each beta
  for idx1 in range(len(a1)):
      for idx2 in range(len(a2)):
          diff_a[idx1][idx2] = a1[idx1]-a2[idx2]
          pass
      pass

  for idx1 in range(len(b1)):
      for idx2 in range(len(b2)):
          diff_b[idx1][idx2] = b1[idx1]-b2[idx2]
          pass
      pass

  # flatten to 1d
  diff_a = diff_a.flatten()
  diff_b = diff_b.flatten()

  # convert to MCSamples so it can be plotted with gdplot
  diff = MCSamples(samples = [diff_a,diff_b],names=['da','db'], labels=['\\Delta \\alpha','\\Delta \\beta'])
  
  return diff

def setup_train(diff):
  ####################
  #
  # Train distribution
  #
  ####################

  # defines the distribution we want to map to
  trained_dist = tfd.MultivariateNormalDiag(loc=[0.,0.], scale_diag=[1.,1.])

  x = diff['da']
  y = diff['db']

  # train
  trained_dist = train(trained_dist,x,y,n_maf=1,n=len(x),batch_size=1000,permute=False,n_epochs=5)# The result should not depend on the change of variables z1<->z2 

  return trained_dist

def significance(trained_dist):
  ######################
  #
  # Compute significance
  #
  ######################

  prob = trained_dist.prob([0.,0.])

  n_points = 10000
  n_pass = 0

  _s = trained_dist.sample(n_points)
  _v = trained_dist.prob(_s)
  for val in _v:
      if val>prob:
          n_pass+=1
          
  n_sigma = np.sqrt(2)*scipy.special.erfinv(n_pass/n_points)
  return n_sigma,n_pass/n_points

# %%
def compute_sigvsep(sep):
    print("=========================== \n")
    print(" generating data...\n")
    print("=========================== \n")
    data = gen_data(sep)
    print("=========================== \n")
    print(" training NN...\n")
    print("=========================== \n")
    dist = setup_train(data)
    print("=========================== \n")
    print(" computing n_sigma...\n")
    print("=========================== \n")
    n_sigma = significance(dist)
    print("=========================== \n")
    print(" Done.\n")
    print("=========================== \n")
    return(n_sigma)

result_data = []
sep_arr = np.linspace(0,5,10)

for sep in sep_arr:
    result_data.append([sep,compute_sigvsep(sep)])

print(result_data)
# Out:
# ===========================
#
#  generating data...
#
# ===========================
#
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 10300.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:5.304335, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:04:19 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 1.113978 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.288
# [mcmc]  - Convergence of means: R-1 = 0.097337 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.284
# [mcmc]  - Convergence of means: R-1 = 0.042168 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.041958 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.030032 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.031988 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.022693 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.013333 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.011040 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.028482 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.068685 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.290
# [mcmc]  - Convergence of means: R-1 = 0.035466 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.031134 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.290
# [mcmc]  - Convergence of means: R-1 = 0.027635 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.286
# [mcmc]  - Convergence of means: R-1 = 0.024799 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.288
# [mcmc]  - Convergence of means: R-1 = 0.020421 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.289
# [mcmc]  - Convergence of means: R-1 = 0.010918 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.024645 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.288
# [mcmc]  - Convergence of means: R-1 = 0.025905 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.290
# [mcmc]  - Convergence of means: R-1 = 0.019716 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.013545 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.014190 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.009149 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.012164 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.016306 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.014654 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.006807 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.007377 after 1792 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.077280 after 2240 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 2240 accepted steps.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 12500.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:1.857834, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:04:22 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.229
# [mcmc]  - Convergence of means: R-1 = 0.732309 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.037026 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.068326 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.040157 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.017859 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.014364 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.288
# [mcmc]  - Convergence of means: R-1 = 0.005763 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.291
# [mcmc]  - Convergence of means: R-1 = 0.016907 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.283
# [mcmc]  - Convergence of means: R-1 = 0.015728 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.286
# [mcmc]  - Convergence of means: R-1 = 0.011154 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.010719 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.027466 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.011864 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.015923 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.011754 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.018775 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.018583 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.010817 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.010364 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.004014 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.010843 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.006441 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.013523 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.008362 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.007450 after 1600 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.126875 after 2000 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 2000 accepted steps.
# [root] *WARNING* outlier fraction 0.005357142857142857
# [root] *WARNING* outlier fraction 0.013
# ===========================
#
#  training NN...
#
# ===========================
#
# Starting training...
# Begin Epoch 0...
# End Epoch 4. Loss = 3.67496. Validation loss = 3.70615
# Completed training!
# ===========================
#
#  computing n_sigma...
#
# ===========================
#
# ===========================
#
#  Done.
#
# ===========================
#
# ===========================
#
#  generating data...
#
# ===========================
#
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 4540.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:-4.325695, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:05:07 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.373053 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.245720 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.241152 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.110203 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.331
# [mcmc]  - Convergence of means: R-1 = 0.076426 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.328
# [mcmc]  - Convergence of means: R-1 = 0.045884 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.315
# [mcmc]  - Convergence of means: R-1 = 0.027627 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.316
# [mcmc]  - Convergence of means: R-1 = 0.030900 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.316
# [mcmc]  - Convergence of means: R-1 = 0.006438 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.315
# [mcmc]  - Convergence of means: R-1 = 0.019377 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.314
# [mcmc]  - Convergence of means: R-1 = 0.025608 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.314
# [mcmc]  - Convergence of means: R-1 = 0.021987 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.315
# [mcmc]  - Convergence of means: R-1 = 0.015661 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.018607 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.312
# [mcmc]  - Convergence of means: R-1 = 0.012543 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.005343 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.011647 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.004397 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.008279 after 1216 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.165566 after 1520 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1520 accepted steps.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 12500.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:9.173433, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:05:09 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.278
# [mcmc]  - Convergence of means: R-1 = 0.223571 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.284
# [mcmc]  - Convergence of means: R-1 = 0.056084 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.212315 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.333
# [mcmc]  - Convergence of means: R-1 = 0.163721 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.362
# [mcmc]  - Convergence of means: R-1 = 0.063993 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.360
# [mcmc]  - Convergence of means: R-1 = 0.045294 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.356
# [mcmc]  - Convergence of means: R-1 = 0.022335 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.346
# [mcmc]  - Convergence of means: R-1 = 0.046537 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.339
# [mcmc]  - Convergence of means: R-1 = 0.007972 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.339
# [mcmc]  - Convergence of means: R-1 = 0.031112 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.339
# [mcmc]  - Convergence of means: R-1 = 0.029973 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.333
# [mcmc]  - Convergence of means: R-1 = 0.033555 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.012397 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.315
# [mcmc]  - Convergence of means: R-1 = 0.015431 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.309
# [mcmc]  - Convergence of means: R-1 = 0.021136 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.311
# [mcmc]  - Convergence of means: R-1 = 0.029411 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.035026 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.013751 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.005055 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.018835 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.018214 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.016964 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.019344 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.012836 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.004674 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.004342 after 1664 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.086513 after 2080 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 2080 accepted steps.
# [root] *WARNING* outlier fraction 0.034868421052631576
# [root] *WARNING* outlier fraction 0.013461538461538462
# ===========================
#
#  training NN...
#
# ===========================
#
# Starting training...
# Begin Epoch 0...
# End Epoch 4. Loss = 3.64784. Validation loss = 3.67113
# Completed training!
# ===========================
#
#  computing n_sigma...
#
# ===========================
#
# ===========================
#
#  Done.
#
# ===========================
#
# ===========================
#
#  generating data...
#
# ===========================
#
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 13100.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:6.287797, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:06:00 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 1.331213 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.284
# [mcmc]  - Convergence of means: R-1 = 0.742956 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.097674 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.335
# [mcmc]  - Convergence of means: R-1 = 0.034851 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.084983 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.313
# [mcmc]  - Convergence of means: R-1 = 0.064206 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.311
# [mcmc]  - Convergence of means: R-1 = 0.032779 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.043636 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.311
# [mcmc]  - Convergence of means: R-1 = 0.034410 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.025735 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.023548 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.026427 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.017466 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.014515 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.010080 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.023370 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.016585 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.008461 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.004494 after 1216 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.092972 after 1520 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1520 accepted steps.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 10700.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:9.697808, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:06:02 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.201
# [mcmc]  - Convergence of means: R-1 = 0.560097 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.274
# [mcmc]  - Convergence of means: R-1 = 0.068684 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.080133 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.076504 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.309
# [mcmc]  - Convergence of means: R-1 = 0.011114 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.042184 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.033841 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.292
# [mcmc]  - Convergence of means: R-1 = 0.026199 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.286
# [mcmc]  - Convergence of means: R-1 = 0.013157 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.285
# [mcmc]  - Convergence of means: R-1 = 0.014897 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.288
# [mcmc]  - Convergence of means: R-1 = 0.036075 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.009068 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.285
# [mcmc]  - Convergence of means: R-1 = 0.007911 after 832 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.103225 after 1040 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1040 accepted steps.
# [root] *WARNING* outlier fraction 0.031578947368421054
# [root] *WARNING* outlier fraction 0.09711538461538462
# ===========================
#
#  training NN...
#
# ===========================
#
# Starting training...
# Begin Epoch 0...
# End Epoch 4. Loss = 3.73086. Validation loss = 3.71208
# Completed training!
# ===========================
#
#  computing n_sigma...
#
# ===========================
#
# ===========================
#
#  Done.
#
# ===========================
#
# ===========================
#
#  generating data...
#
# ===========================
#
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 12000.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:-3.613758, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:06:30 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.264
# [mcmc]  - Convergence of means: R-1 = 0.035768 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.104347 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.310
# [mcmc]  - Convergence of means: R-1 = 0.093080 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.289
# [mcmc]  - Convergence of means: R-1 = 0.059420 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.068626 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.284
# [mcmc]  - Convergence of means: R-1 = 0.086835 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.283
# [mcmc]  - Convergence of means: R-1 = 0.032324 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.030180 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.033542 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.289
# [mcmc]  - Convergence of means: R-1 = 0.022261 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.295
# [mcmc]  - Convergence of means: R-1 = 0.020753 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.023206 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.018286 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.010683 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.018527 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.007731 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.012812 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.006142 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.004703 after 1216 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.133817 after 1520 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1520 accepted steps.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 18000.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:1.924023, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:06:32 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.822221 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.069949 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.024902 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.046198 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.313
# [mcmc]  - Convergence of means: R-1 = 0.003266 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.074785 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.041021 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.033900 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.306
# [mcmc]  - Convergence of means: R-1 = 0.030679 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.009547 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.021561 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.041555 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.021625 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.010027 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.009084 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.008725 after 1024 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.094497 after 1280 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1280 accepted steps.
# [root] *WARNING* outlier fraction 0.030921052631578946
# [root] *WARNING* outlier fraction 0.07109375
# ===========================
#
#  training NN...
#
# ===========================
#
# Starting training...
# Begin Epoch 0...
# End Epoch 4. Loss = 3.67715. Validation loss = 3.59291
# Completed training!
# ===========================
#
#  computing n_sigma...
#
# ===========================
#
# ===========================
#
#  Done.
#
# ===========================
#
# ===========================
#
#  generating data...
#
# ===========================
#
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 11300.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:1.886086, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:07:01 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.232
# [mcmc]  - Convergence of means: R-1 = 1.024592 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.268
# [mcmc]  - Convergence of means: R-1 = 0.133204 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.279
# [mcmc]  - Convergence of means: R-1 = 0.107277 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.291
# [mcmc]  - Convergence of means: R-1 = 0.058543 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.018235 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.032241 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.309
# [mcmc]  - Convergence of means: R-1 = 0.017826 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.011856 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.026063 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.315
# [mcmc]  - Convergence of means: R-1 = 0.005774 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.316
# [mcmc]  - Convergence of means: R-1 = 0.007810 after 704 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.103306 after 880 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 880 accepted steps.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 15200.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:-0.4211925, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:07:03 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# ...
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.305
# [mcmc]  - Convergence of means: R-1 = 0.021513 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.022288 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.006054 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.008210 after 1600 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.099567 after 2000 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 2000 accepted steps.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 13400.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:1.328306, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:11:24 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.328
# [mcmc]  - Convergence of means: R-1 = 0.988539 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.108832 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.055940 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.312
# [mcmc]  - Convergence of means: R-1 = 0.053812 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.313
# [mcmc]  - Convergence of means: R-1 = 0.025237 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.050996 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.034372 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.042934 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.023335 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.019405 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.291
# [mcmc]  - Convergence of means: R-1 = 0.021471 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.286
# [mcmc]  - Convergence of means: R-1 = 0.019124 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.286
# [mcmc]  - Convergence of means: R-1 = 0.020515 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.010290 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.014737 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.285
# [mcmc]  - Convergence of means: R-1 = 0.010321 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.283
# [mcmc]  - Convergence of means: R-1 = 0.009046 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.285
# [mcmc]  - Convergence of means: R-1 = 0.003567 after 1152 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.060146 after 1440 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1440 accepted steps.
# [root] *WARNING* outlier fraction 0.009
# [root] *WARNING* outlier fraction 0.04513888888888889
# ===========================
#
#  training NN...
#
# ===========================
#
# Starting training...
# Begin Epoch 0...
# End Epoch 4. Loss = 3.71649. Validation loss = 3.76754
# Completed training!
# ===========================
#
#  computing n_sigma...
#
# ===========================
#
# ===========================
#
#  Done.
#
# ===========================
#
# ===========================
#
#  generating data...
#
# ===========================
#
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 14000.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:-0.5052071, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:12:14 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.256
# [mcmc]  - Convergence of means: R-1 = 0.558394 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.156282 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.119348 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.315
# [mcmc]  - Convergence of means: R-1 = 0.041630 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.033320 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.016577 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.022702 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.288
# [mcmc]  - Convergence of means: R-1 = 0.012295 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.275
# [mcmc]  - Convergence of means: R-1 = 0.029124 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.274
# [mcmc]  - Convergence of means: R-1 = 0.006623 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.280
# [mcmc]  - Convergence of means: R-1 = 0.005535 after 704 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.112641 after 880 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 880 accepted steps.
# [mcmc] Getting initial point... (this may take a few seconds)
# [prior] Reference values or pdfs for some parameters were not provided. Sampling from the prior instead for those parameters.
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {gaussian_mixture: 14600.0}
# [prior] *WARNING* Reference pdf not defined or improper for some parameters. Using prior's sigma instead for them.
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Initial point: a:8.978103, b:0
# [mcmc] Sampling!
# [mcmc] Progress @ 2022-04-08 19:12:15 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.253
# [mcmc]  - Convergence of means: R-1 = 0.711708 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.248115 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.371148 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.148765 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.048514 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.002307 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.023273 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.096401 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.038198 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.291
# [mcmc]  - Convergence of means: R-1 = 0.072007 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.030629 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.038440 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.028706 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.023453 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.038306 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.019028 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.011818 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.013459 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.290
# [mcmc]  - Convergence of means: R-1 = 0.018928 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.293
# [mcmc]  - Convergence of means: R-1 = 0.030714 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.296
# [mcmc]  - Convergence of means: R-1 = 0.015744 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.298
# [mcmc]  - Convergence of means: R-1 = 0.009761 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.297
# [mcmc]  - Convergence of means: R-1 = 0.005205 after 1472 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.115453 after 1840 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 1840 accepted steps.
# [root] *WARNING* outlier fraction 0.09659090909090909
# [root] *WARNING* outlier fraction 0.017391304347826087
# ===========================
#
#  training NN...
#
# ===========================
#
# Starting training...
# Begin Epoch 0...
# End Epoch 4. Loss = 3.70662. Validation loss = 3.64755
# Completed training!
# ===========================
#
#  computing n_sigma...
#
# ===========================
#
# ===========================
#
#  Done.
#
# ===========================
#
# [[0.0, (0.0015039775317651203, 0.0012)], [0.5555555555555556, (0.1054736217688682, 0.084)], [1.1111111111111112, (0.28388305846751494, 0.2235)], [1.6666666666666667, (0.5777987489791598, 0.4366)], [2.2222222222222223, (0.996309066348687, 0.6809)], [2.7777777777777777, (1.3670807383113872, 0.8284)], [3.3333333333333335, (1.709275118381712, 0.9126)], [3.8888888888888893, (2.0475919376336646, 0.9594)], [4.444444444444445, (2.4702994283625896, 0.9865)], [5.0, (2.721430761482366, 0.9935)]]

# %%
x = []
y = []
z = []

for i in range(len(result_data)):
  print(result_data[i])
  x.append(result_data[i][0])
  y.append(result_data[i][1][0])
  z.append(result_data[i][1][1])

plt.xlabel('separation')
plt.ylabel('n_\sigma')
plt.plot(x,y)
plt.show()
plt.xlabel('separation')
plt.ylabel('p_{shift}')
plt.plot(x,z)
plt.show()
# Out:
# [0.0, (0.0015039775317651203, 0.0012)]
# [0.5555555555555556, (0.1054736217688682, 0.084)]
# [1.1111111111111112, (0.28388305846751494, 0.2235)]
# [1.6666666666666667, (0.5777987489791598, 0.4366)]
# [2.2222222222222223, (0.996309066348687, 0.6809)]
# [2.7777777777777777, (1.3670807383113872, 0.8284)]
# [3.3333333333333335, (1.709275118381712, 0.9126)]
# [3.8888888888888893, (2.0475919376336646, 0.9594)]
# [4.444444444444445, (2.4702994283625896, 0.9865)]
# [5.0, (2.721430761482366, 0.9935)]
