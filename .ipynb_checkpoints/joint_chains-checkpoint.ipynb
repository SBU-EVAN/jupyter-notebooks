# %% [markdown]
# ## Joint MCMC Sampling
# This notebook attemps to sample from the joint posterior of planck and LSST. The emulators are used to calculate the likelihood. For parameters in planck but not LSST the joint prior is extended to be uninformative in the new parameters. Since the experiments are independent the joint likelihood is simply the sum/product.

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from getdist import plots, MCSamples
import getdist
from multiprocessing import Pool
from getdist import plots, MCSamples, WeightedSamples

import sys
import time

sys.path.append(os.path.join(os.path.dirname("__file__"), '../'))
# LSST
from cocoa_emu import *
from cocoa_emu.emulator import NNEmulator, GPEmulator
from cocoa_emu.data_model import LSST_3x2

# cosmopower

import emcee
import time

# Now normalizing flow
import tensorflow as tf
import tensorflow_probability as tfp
tfb = tfp.bijectors
tfd = tfp.distributions
tfk = tf.keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.callbacks import Callback

from numpy import linalg
import scipy

# %matplotlib inline

# %%
### Planck MCMC

# %%
### LSST MCMC Functions
def add_bias(bias_theta, datavector):
    for i in range(5):
        factor = (bias_theta[i] / bias_fid[i])**bias_mask[i]
        datavector = factor * datavector
    return datavector

def add_shear_calib(m, datavector):
    for i in range(5):
        factor = (1 + m[i])**shear_calib_mask[i]
        datavector = factor * datavector
    return datavector

def hard_prior(theta, params_prior):
    """
    A function to impose a flat prior on a set of parameters.
    :theta: The set of parameter values
    :params_prior: The minimum and the maximum value of the parameters on which this prior is imposed
    """
    is_lower_than_min = bool(np.sum(theta < params_prior[:,0]))
    is_higher_than_max = bool(np.sum(theta > params_prior[:,1]))
    if is_lower_than_min or is_higher_than_max:
        return -np.inf
    else:
        return 0.
    
cosmo_prior_lim = np.array([[1.61, 3.91],
                       [0.87, 1.07],
                       [55, 91],
                       [0.01, 0.04],
                       [0.001, 0.99]])

ia_prior_lim = np.array([[-5., 5.],
                       [-5., 5.]])

bias_prior_lim = np.array([[0.8, 3.],
                       [0.8, 3.],
                       [0.8, 3.],
                       [0.8, 3.],
                       [0.8, 3.]])

baryon_prior_lim = np.array([[-3., 12.],
                             [-2.5, 2.5]])

baryon_prior_lim = 3. * baryon_prior_lim 

dz_source_std   = 0.002 * np.ones(5)
dz_lens_std     = 0.005 * np.ones(5)
shear_calib_std = 0.005 * np.ones(5)
    
def lnprior(theta):
    cosmo_theta = theta[:5]
    ns          = cosmo_theta[1]

    ns_prior    = 0.
    
    dz_source   = theta[5:10]
    ia_theta    = theta[10:12]
    dz_lens     = theta[12:17]
    bias        = theta[17:22]
    shear_calib = theta[22:27]
    baryon_q    = theta[27:29]
    
    cosmo_prior = hard_prior(cosmo_theta, cosmo_prior_lim) + ns_prior
    ia_prior    = hard_prior(ia_theta, ia_prior_lim)
    bias_prior  = hard_prior(bias, bias_prior_lim)
    baryon_prior = hard_prior(baryon_q, baryon_prior_lim)
    
    dz_source_lnprior   = -0.5 * np.sum((dz_source / dz_source_std)**2)
    dz_lens_lnprior     = -0.5 * np.sum((dz_lens / dz_lens_std)**2)
    shear_calib_lnprior = -0.5 * np.sum((shear_calib / shear_calib_std)**2)
    
    return cosmo_prior + ia_prior + dz_source_lnprior + dz_lens_lnprior + \
            shear_calib_lnprior + bias_prior + baryon_prior
    
def ln_lkl(theta):
    model_datavector = get_data_vector_emu(theta)
    delta_dv = (model_datavector - data_model.dv_obs)[data_model.mask_3x2]
    return -0.5 * delta_dv @ data_model.masked_inv_cov @ delta_dv

def lnprob(theta):
    return lnprior(theta) + ln_lkl(theta) + planck_ln_lkl(theta)

def get_data_vector_emu(theta):
    """
    Function to get the emulated data vector (including the effect of galaxy bias, baryons, etc.)
    """
    cosmo_ia_dz_theta = theta[:17]
    bias        = theta[17:22]
    shear_calib = theta[22:27]
    baryon_q    = theta[27:29]
    datavector = data_model.compute_datavector(cosmo_ia_dz_theta)
    datavector = np.array(datavector)
    datavector = add_bias(bias, datavector)
    datavector = add_shear_calib(shear_calib, datavector)
    return datavector

# %%
### Planck MCMC functions
#
# from LSST emulator for index reference
# names = ['logA', 'ns', 'H0', 'omegab', 'omegac']

def planck_ln_lkl(theta):
    pspec = theta[0:2]
    densities = theta[3:5]
    planck2 = theta[29:31]
    #planck2 = theta[5:7]
    theta_planck = [densities[0],densities[1],planck2[0],planck2[1],pspec[0],pspec[1]]
    lkl = trained_dist.log_prob(theta_planck).numpy()
    return lkl

# %%
# open the emulator
# Get the LSST covariance and fid data
path = '/home/grads/data/evan/tension_calibration/data/lsst_y1/'
lsst_cov = np.loadtxt(path+'cov_lsst_y1')
fid_cos = np.loadtxt(path+'lsst_y1_data_fid',dtype=np.float32)[:,1]

lsst_y1_cov = np.zeros((1560, 1560))
for line in lsst_cov:
    i = int(line[0])
    j = int(line[1])

    cov_g_block  = line[-2]
    cov_ng_block = line[-1]

    cov_ij = cov_g_block + cov_ng_block

    lsst_y1_cov[i,j] = cov_ij
    lsst_y1_cov[j,i] = cov_ij
    
fid = torch.Tensor(fid_cos)
cov = torch.Tensor(lsst_y1_cov)

configfile = 'configs/nn_emu.yaml'
config = Config(configfile)

config_args     = config.config_args
config_args_io  = config_args['io']
config_args_data = config_args['data']

savedir = 'output/nn_emu/'

N_DIM         = 17
data_model    = LSST_3x2(N_DIM, config_args_io, config_args_data)
data_model.emu_type = 'nn'
OUTPUT_DIM = 1560

emu = NNEmulator(N_DIM, OUTPUT_DIM, data_model.dv_fid, data_model.dv_std)    
emu.load('model/nn_emu/model')
# ======================================================

data_model.emu = emu

bias_fid         = data_model.bias_fid
bias_mask        = data_model.bias_mask
shear_calib_mask = data_model.shear_calib_mask

N_MCMC        = 5000
N_WALKERS     = 120
NDIM_SAMPLING = 31

theta0    = np.array([3.0675, 0.97, 69.0, 0.0228528, 0.1199772, 
                      0., 0., 0., 0., 0.,
                      0.5, 0.,
                      0., 0., 0., 0., 0.,
                      1.24, 1.36, 1.47, 1.60, 1.76,
                      0., 0., 0., 0., 0.,
                      0., 0.,1.05,0.05])

theta_std = np.array([0.01, 0.001, 0.1, 0.001, 0.002, 
                      0.002, 0.002, 0.002, 0.002, 0.002, 
                      0.1, 0.1,
                      0.005, 0.005, 0.005, 0.005, 0.005, 
                      0.03, 0.03, 0.03, 0.03, 0.03,
                      0.005, 0.005, 0.005, 0.005, 0.005, 
                      0.1, 0.1,0.01,0.01]) 

# Starting position of the emcee chain
pos0 = theta0[np.newaxis] + 3. * theta_std[np.newaxis] * np.random.normal(size=(N_WALKERS, NDIM_SAMPLING))

# %%
start_time = time.time()
#with Pool(10) as pool:
emu_sampler = emcee.EnsembleSampler(N_WALKERS, NDIM_SAMPLING, lnprob)#, pool=pool)
emu_sampler.run_mcmc(pos0, N_MCMC, progress=True)
# Out:
#   5%|████▍                                                                              | 271/5000 [1:42:41<28:55:40, 22.02s/it]Traceback (most recent call last):
#   File "/home/grads/.local/lib/python3.7/site-packages/emcee/ensemble.py", line 624, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/tmp/ipykernel_3588439/1301226312.py", line 82, in lnprob
#     return lnprior(theta) + ln_lkl(theta) + planck_ln_lkl(theta)
#   File "/tmp/ipykernel_3588439/1462940827.py", line 12, in planck_ln_lkl
#     lkl = trained_dist.log_prob(theta_planck).numpy()
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/distributions/distribution.py", line 1315, in log_prob
#     return self._call_log_prob(value, name, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/distributions/distribution.py", line 1297, in _call_log_prob
#     return self._log_prob(value, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/distributions/transformed_distribution.py", line 385, in _log_prob
#     y, event_ndims=event_ndims, **bijector_kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py", line 1539, in inverse_log_det_jacobian
#     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/composition.py", line 545, in _call_inverse_log_det_jacobian
#     return self._inverse_log_det_jacobian(y, event_ndims, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/composition.py", line 559, in _inverse_log_det_jacobian
#     **bm.kwargs),
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py", line 1539, in inverse_log_det_jacobian
#     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py", line 1467, in _call_inverse_log_det_jacobian
#     ildj = attrs['ildj'] = self._inverse_log_det_jacobian(y, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py", line 391, in _inverse_log_det_jacobian
#     y, event_ndims=self._event_ndims)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py", line 1539, in inverse_log_det_jacobian
#     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/composition.py", line 545, in _call_inverse_log_det_jacobian
#     return self._inverse_log_det_jacobian(y, event_ndims, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/composition.py", line 559, in _inverse_log_det_jacobian
#     **bm.kwargs),
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py", line 1539, in inverse_log_det_jacobian
#     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py", line 1495, in _call_inverse_log_det_jacobian
#     ildj, reduce_shape, sum_fn=self._sum_fn)
#   File "/home/grads/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py", line 2308, in reduce_jacobian_det_over_shape
#     return sum_fn(ones * unreduced, axis=reduce_dims)
#   File "/home/grads/.local/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/home/grads/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py", line 1406, in binary_op_wrapper
#     return func(x, y, name=name)
#   File "/home/grads/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py", line 1766, in _mul_dispatch
#     return multiply(x, y, name=name)
#   File "/home/grads/.local/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/home/grads/.local/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py", line 1082, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#   File "/home/grads/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py", line 529, in multiply
#     return gen_math_ops.mul(x, y, name)
#   File "/home/grads/.local/lib/python3.7/site-packages/tensorflow/python/ops/gen_math_ops.py", line 6577, in mul
#     _ctx, "Mul", name, x, y)
# KeyboardInterrupt
#   5%|████▍                                                                              | 271/5000 [1:42:58<29:56:58, 22.80s/it]
# emcee: Exception while calling your likelihood function:
#   params: [ 3.00749479e+00  9.73940776e-01  6.85569002e+01  2.45176903e-02
#   1.23884027e-01  1.22996855e-02  5.29085051e-03  3.43080130e-03
#  -2.78284091e-03 -4.77123647e-03  4.54882565e-01  8.54006383e-02
#  -1.49049120e-03  1.05458705e-02 -4.45956840e-03  3.27112780e-03
#   1.21635168e-02  1.25118994e+00  1.52026240e+00  1.61108837e+00
#   1.65858342e+00  1.81418948e+00  7.76174252e-04 -1.80056055e-02
#   3.84129974e-03  1.80122119e-02  6.41262451e-03 -2.86375424e-01
#   9.25519685e-01  1.05076132e+00  1.14128687e-01]
#   args: []
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3588439/926680407.py in <module>
#       2 #with Pool(10) as pool:
#       3 emu_sampler = emcee.EnsembleSampler(N_WALKERS, NDIM_SAMPLING, lnprob)#, pool=pool)
# ----> 4 emu_sampler.run_mcmc(pos0, N_MCMC, progress=True)
#
# ~/.local/lib/python3.7/site-packages/emcee/ensemble.py in run_mcmc(self, initial_state, nsteps, **kwargs)
#     441
#     442         results = None
# --> 443         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     444             pass
#     445
#
# ~/.local/lib/python3.7/site-packages/emcee/ensemble.py in sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     400
#     401                     # Propose
# --> 402                     state, accepted = move.propose(model, state)
#     403                     state.random_state = self.random_state
#     404
#
# ~/.local/lib/python3.7/site-packages/emcee/moves/red_blue.py in propose(self, model, state)
#      91
#      92             # Compute the lnprobs of the proposed position.
# ---> 93             new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      94
#      95             # Loop over the walkers and update them accordingly.
#
# ~/.local/lib/python3.7/site-packages/emcee/ensemble.py in compute_log_prob(self, coords)
#     487             else:
#     488                 map_func = map
# --> 489             results = list(map_func(self.log_prob_fn, p))
#     490
#     491         try:
#
# ~/.local/lib/python3.7/site-packages/emcee/ensemble.py in __call__(self, x)
#     622     def __call__(self, x):
#     623         try:
# --> 624             return self.f(x, *self.args, **self.kwargs)
#     625         except:  # pragma: no cover
#     626             import traceback
#
# /tmp/ipykernel_3588439/1301226312.py in lnprob(theta)
#      80
#      81 def lnprob(theta):
# ---> 82     return lnprior(theta) + ln_lkl(theta) + planck_ln_lkl(theta)
#      83
#      84 def get_data_vector_emu(theta):
#
# /tmp/ipykernel_3588439/1462940827.py in planck_ln_lkl(theta)
#      10     #planck2 = theta[5:7]
#      11     theta_planck = [densities[0],densities[1],planck2[0],planck2[1],pspec[0],pspec[1]]
# ---> 12     lkl = trained_dist.log_prob(theta_planck).numpy()
#      13     return lkl
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/distributions/distribution.py in log_prob(self, value, name, **kwargs)
#    1313         values of type `self.dtype`.
#    1314     """
# -> 1315     return self._call_log_prob(value, name, **kwargs)
#    1316
#    1317   def _call_prob(self, value, name, **kwargs):
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/distributions/distribution.py in _call_log_prob(self, value, name, **kwargs)
#    1295     with self._name_and_control_scope(name, value, kwargs):
#    1296       if hasattr(self, '_log_prob'):
# -> 1297         return self._log_prob(value, **kwargs)
#    1298       if hasattr(self, '_prob'):
#    1299         return tf.math.log(self._prob(value, **kwargs))
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/distributions/transformed_distribution.py in _log_prob(self, y, **kwargs)
#     383
#     384     ildj = self.bijector.inverse_log_det_jacobian(
# --> 385         y, event_ndims=event_ndims, **bijector_kwargs)
#     386     if self.bijector._is_injective:  # pylint: disable=protected-access
#     387       base_log_prob = self.distribution.log_prob(x, **distribution_kwargs)
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py in inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1537       ValueError: if the value of `event_ndims` is not valid for this bijector.
#    1538     """
# -> 1539     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#    1540
#    1541   def _call_forward_log_det_jacobian(self, x, event_ndims, name, **kwargs):
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/composition.py in _call_inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#     543       event_ndims = nest_util.coerce_structure(
#     544           self.inverse_min_event_ndims, event_ndims)
# --> 545       return self._inverse_log_det_jacobian(y, event_ndims, **kwargs)
#     546
#     547   def _inverse_log_det_jacobian(self, y, event_ndims, **kwargs):
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/composition.py in _inverse_log_det_jacobian(self, y, event_ndims, **kwargs)
#     557       ldj = tf.convert_to_tensor(
#     558           bm.bijector.inverse_log_det_jacobian(bm.x, bm.x_event_ndims,
# --> 559                                                **bm.kwargs),
#     560           dtype_hint=ldj_sum.dtype)
#     561
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py in inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1537       ValueError: if the value of `event_ndims` is not valid for this bijector.
#    1538     """
# -> 1539     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#    1540
#    1541   def _call_forward_log_det_jacobian(self, x, event_ndims, name, **kwargs):
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py in _call_inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1465           ildj = attrs['ildj']
#    1466         elif hasattr(self, '_inverse_log_det_jacobian'):
# -> 1467           ildj = attrs['ildj'] = self._inverse_log_det_jacobian(y, **kwargs)
#    1468         elif hasattr(self, '_forward_log_det_jacobian'):
#    1469           x = self.inverse(y, **kwargs)  # Fall back to computing `-fldj(x)`
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/masked_autoregressive.py in _inverse_log_det_jacobian(self, y, **kwargs)
#     389   def _inverse_log_det_jacobian(self, y, **kwargs):
#     390     return self._bijector_fn(y, **kwargs).inverse_log_det_jacobian(
# --> 391         y, event_ndims=self._event_ndims)
#     392
#     393
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py in inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1537       ValueError: if the value of `event_ndims` is not valid for this bijector.
#    1538     """
# -> 1539     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#    1540
#    1541   def _call_forward_log_det_jacobian(self, x, event_ndims, name, **kwargs):
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/composition.py in _call_inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#     543       event_ndims = nest_util.coerce_structure(
#     544           self.inverse_min_event_ndims, event_ndims)
# --> 545       return self._inverse_log_det_jacobian(y, event_ndims, **kwargs)
#     546
#     547   def _inverse_log_det_jacobian(self, y, event_ndims, **kwargs):
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/composition.py in _inverse_log_det_jacobian(self, y, event_ndims, **kwargs)
#     557       ldj = tf.convert_to_tensor(
#     558           bm.bijector.inverse_log_det_jacobian(bm.x, bm.x_event_ndims,
# --> 559                                                **bm.kwargs),
#     560           dtype_hint=ldj_sum.dtype)
#     561
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py in inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1537       ValueError: if the value of `event_ndims` is not valid for this bijector.
#    1538     """
# -> 1539     return self._call_inverse_log_det_jacobian(y, event_ndims, name, **kwargs)
#    1540
#    1541   def _call_forward_log_det_jacobian(self, x, event_ndims, name, **kwargs):
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py in _call_inverse_log_det_jacobian(self, y, event_ndims, name, **kwargs)
#    1493
#    1494         return reduce_jacobian_det_over_shape(
# -> 1495             ildj, reduce_shape, sum_fn=self._sum_fn)
#    1496
#    1497   def inverse_log_det_jacobian(self,
#
# ~/.conda/envs/emu/lib/python3.7/site-packages/tensorflow_probability/python/bijectors/bijector.py in reduce_jacobian_det_over_shape(unreduced, reduce_shape, sum_fn)
#    2306   ones = tf.ones(reduce_shape, unreduced.dtype)
#    2307   reduce_dims = ps.range(-ps.size(reduce_shape), 0)
# -> 2308   return sum_fn(ones * unreduced, axis=reduce_dims)
#    2309
#    2310
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#    1404         #   r_binary_op_wrapper use different force_same_dtype values.
#    1405         x, y = maybe_promote_tensors(x, y)
# -> 1406         return func(x, y, name=name)
#    1407       except (TypeError, ValueError) as e:
#    1408         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in _mul_dispatch(x, y, name)
#    1764     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1765   else:
# -> 1766     return multiply(x, y, name=name)
#    1767
#    1768
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in multiply(x, y, name)
#     527   """
#     528
# --> 529   return gen_math_ops.mul(x, y, name)
#     530
#     531
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/ops/gen_math_ops.py in mul(x, y, name)
#    6575     try:
#    6576       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 6577         _ctx, "Mul", name, x, y)
#    6578       return _result
#    6579     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
